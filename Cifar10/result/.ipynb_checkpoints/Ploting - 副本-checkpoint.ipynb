# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import glob
import statistics
import pandas as pd
# %matplotlib inline

# %%
def es_point(s,p):
    max_index=np.where(s[2]==np.amax(s[2]))
    max_index=max_index[0]+p
    return max_index[0]

# %%
def windowed(s,window_size_half):
    s1=[]
    sv=[]
    window_size = window_size_half*2
    for i in range(len(s)-window_size):
        k = i + window_size_half
        d=s[k-window_size_half:k+window_size_half]
        dm=sum(d)/window_size
        s1.append(dm)
        dv=statistics.variance(d)
        sv.append(dv)
    return s1,sv

# %%
def plot_line(files,i,linelab = ''):
    fileset = pd.concat( [pd.read_csv(f,header=None,sep=' ',names=['loss','acc'])['acc'] for f in files], axis=1)
    set_mean = fileset.mean(axis=1)
    set_plt = [i for i in range(len(set_mean))]
#     ax[i].plot(set_plt,set_mean,label=linelab)
    return set_mean

# %% [markdown]
# ## Central

# %%
basedir=os.path.join('zCentral')
# os.listdir(basedir)

# %%
result=[
    '100_central.batch50.npy',
    '400_central.batch50.npy',
    '800_central.batch50.npy',
    '4000_central.batch50.npy'
]
for res in result:
    s1=np.load(os.path.join(basedir,res))
    plt.plot(s1[0],s1[2], label=res[:-12])
    plt.gcf().set_size_inches(10, 5)
    plt.ylim([0, 1])
    plt.legend()

# %% [markdown]
# ## Data Dispersion

# %%
# basedir=os.path.join('DataDispersion')
# # os.listdir(basedir)

# %%
# fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True, figsize=(18, 6))

# result=[
#  '2c.10W_4000.loc1.earlystop500.20200417-085230.npy',
#  '2c.40W_4000.loc1.earlystop500.20200421-155338.npy',
#  '2c.80W_4000.loc1.earlystop500.20200424-225252.npy',

#  '5c.10W_4000.loc1.earlystop500.20200417-042135.npy',
#  '5c.40W_4000.loc1.earlystop500.20200419-125703.npy',
#  '5c.80W_4000.loc1.earlystop500.20200423-163133.npy',
    
#  'iid.10W_4000.loc1.earlystop500.20200417-074006.npy',
#  'iid.40W_4000.loc1.earlystop500.20200420-075052.npy',
#  'iid.80W_4000.loc1.earlystop500.20200423-052557.npy',
# ]

# lab=[
#  '2c.10W',
#  '2c.40W',
#  '2c.80W',
    
#  '5c.10W',
#  '5c.40W',
#  '5c.80W',
    
#  'iid.10W',
#  'iid.40W',
#  'iid.80W',
# ] 

# # for i in range(3):
# #     for j in range(3):
# #         s=np.load(os.path.join(basedir,result[i*3+j]))
# #         p=es_point(s,500)
# #         half_window_size=25
# #         (s_mean,s_varience)=windowed(s[2][:p],half_window_size)
# #         s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
# # #         ax[i].plot(s_epo,s_mean, label=lab[i*3+j])
# #         ax[i].plot(s_epo,s_varience, label=lab[i*3+j]+'_var')

    
    
# #     ax[i].set_xlabel('Epoch',fontsize=16)
# #     ax[i].grid(axis="y",ls='-.')
# #     ax[0].set_ylabel('Accuracy',fontsize=16)
# #     ax[i].legend() 

# ###############################################################################################
# for i in range(3):
#     for j in range(3):
#         s1=np.load(os.path.join(basedir,result[i*3+j]))
#         p=es_point(s1,500)
#         ax[i].plot(s1[0][:p],s1[2][:p], label=lab[i*3+j])
# #         index_max=np.argmax(s1[2])
# #         ax[i].plot(index_max,s1[2][index_max],'ks')
# #         ax[i].annotate('{:.3f}'.format(s1[2][index_max]),
# #                        xytext=(index_max,s1[2][index_max]),
# #                        xy=(index_max,s1[2][index_max])
# #                       )
    
#     ax[i].set_xlabel('Epoch',fontsize=16)
#     ax[i].grid(axis="y",ls='-.')
#     ax[0].set_ylabel('Accuracy',fontsize=16)
#     ax[i].legend()

# %% [markdown]
# ## Bad Node

# %%
basedir=os.path.join('BadNode')
# os.listdir(basedir)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True, figsize=(18, 6))

result=[
 '2c.10w.4000.plus1bad_each40.loc1.earlystop500.20200501-015142.npy',
 '2c.10w.4000.plus1bad_each400.loc1.earlystop500.20200501-031558.npy',
 '5c.10w.4000.plus1bad_each40.loc1.earlystop500.20200501-023155.npy',
 '5c.10w.4000.plus1bad_each400.loc1.earlystop500.20200501-004052.npy',
 '11d.10w.4000.plus1bad_each40.loc1.earlystop500.20200501-020918.npy',
 '11d.10w.4000.plus1bad_each400.loc1.earlystop500.20200501-060927.npy'
       ]

lab=[
 '2c.bad1_40',
 '2c.bad1_400',
 '5c.bad1_40',
 '5c.bad1_400',
 'iid.bad1_40',
 'iid.bad1_400'
       ]

node_dir = [
    'bad2c40',
    'bad2c400',
    'bad5c40',
    'bad5c400',
    'badiid40',
    'badiid400'
]

for i in range(3):
    
    for j in range(2):
        s1=np.load(os.path.join(basedir,result[i*2+j]))
        p=es_point(s1,500)
        half_window_size=25
        (s_mean,s_varience)=windowed(s1[2][:p],half_window_size)
        s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
#         ax[i].plot(s_epo,s_mean, label=lab[i*2+j])
        ax[i].plot(s_epo,s_varience, label=lab[i*2+j]+'_var')
        
        # see how training data fit
        files = glob.glob(basedir +'/'+ node_dir[i*2+j]+ '/worker_nodes/*/self_EVAL.txt')
        linelab = lab[i*2+j] + '_traindata'
        set_mean = plot_line(files,i,linelab)
        (s_mean,s_varience)=windowed(set_mean,half_window_size)
        s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
#         ax[i].plot(s_epo,s_mean, label=linelab)
        ax[i].plot(s_epo,s_varience, label=linelab+'_var')
    
    
    ax[i].set_xlabel('Epoch',fontsize=16)
    ax[i].set_ylim([0, 1])
    ax[i].grid(axis="y",ls='-.')
    ax[0].set_ylabel('Accuracy',fontsize=16)
    ax[i].legend() 
#####################################################################################################################

# for i in range(3):
    
#     for j in range(2):
#         s1=np.load(os.path.join(basedir,result[i*2+j]))
#         p=es_point(s1,500)
#         ax[i].plot(s1[0][:p],s1[2][:p], label=lab[i*2+j])
        
# #         # see how training data fit
# #         files = glob.glob(basedir +'/'+ node_dir[i*2+j]+ '/worker_nodes/*/self_EVAL.txt')
# #         linelab = lab[i*2+j] + '_traindata'
# #         set_mean = plot_line(files,i,linelab)
# #         set_plt = [i for i in range(len(set_mean))]
# #         ax[i].plot(set_plt,set_mean, label=linelab)

#           #  show the highest point
# #         index_max=np.argmax(s1[2])
# #         ax[i].plot(index_max,s1[2][index_max],'ks')
# #         ax[i].annotate('{:.3f}'.format(s1[2][index_max]),
# #                        xytext=(index_max,s1[2][index_max]),
# #                        xy=(index_max,s1[2][index_max])
# #                       )
    
    
#     ax[i].set_xlabel('Epoch',fontsize=16)
#     ax[i].set_ylim([0, 1])
#     ax[i].grid(axis="y",ls='-.')
#     ax[0].set_ylabel('Accuracy',fontsize=16)
#     ax[i].legend()

# %% [markdown]
# ## Local Steps

# %%
basedir=os.path.join('LocalStep')
os.listdir(basedir)
# Out:
# ['2c.10w.4000.loc1.earlystop500.20200501-072809.npy',
#  '2c.10w.4000.loc10.earlystop500.20200502-105042.npy',
#  '5c.10w.4000.loc1.earlystop500.20200501-024326.npy',
#  '5c.10w.4000.loc10.earlystop500.20200501-203358.npy',
#  'iid.10w.4000.loc1.earlystop500.20200501-020117.npy',
#  'iid.10w.4000.loc10.earlystop500.20200502-151734.npy',
#  'loc2c10s',
#  'loc2c1s',
#  'loc5c10s',
#  'loc5c1s',
#  'lociid10s',
#  'lociid1s']

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True, figsize=(18, 6))

result=[
'2c.10w.4000.loc1.earlystop500.20200501-072809.npy',
'2c.10w.4000.loc10.earlystop500.20200502-105042.npy',
'5c.10w.4000.loc1.earlystop500.20200501-024326.npy',
'5c.10w.4000.loc10.earlystop500.20200501-203358.npy',
'iid.10w.4000.loc1.earlystop500.20200501-020117.npy',
'iid.10w.4000.loc10.earlystop500.20200502-151734.npy'
]

lab=[
    '2c.loc1',
    '2c.loc10',
    '5c.loc1',
    '5c.loc10',
    'iid.loc1',
    'iid.loc10'
]

node_dir = [
 'loc2c1s',
 'loc2c10s',
 'loc5c1s',
 'loc5c10s',
 'lociid1s',
 'lociid10s'
]


x = 2




for i in range(3):
    
    for j in range(x):
        s1=np.load(os.path.join(basedir,result[i*x+j]))
        p=es_point(s1,500)
        half_window_size=25
        (s_mean,s_varience)=windowed(s1[2][:p],half_window_size)
        s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
        ax[i].plot(s_epo,s_mean, label=lab[i*x+j])
#         ax[i].plot(s_epo[10:],s_varience[10:], label=lab[i*x+j]+'_var')
        
        # see how training data fit
        files = glob.glob(basedir +'/'+ node_dir[i*x+j]+ '/worker_nodes/*/self_EVAL.txt')
        linelab = lab[i*2+j] + '_traindata'
        set_mean = plot_line(files,i,linelab)
        (s_mean,s_varience)=windowed(set_mean,half_window_size)
        s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
        ax[i].plot(s_epo,s_mean, label=linelab)
#         ax[i].plot(s_epo[10:],s_varience[10:], label=linelab+'_var')
    
    
    ax[i].set_xlabel('Epoch',fontsize=16)
    ax[i].set_ylim([0, 1.1])
    ax[i].grid(axis="y",ls='-.')
    ax[0].set_ylabel('Accuracy',fontsize=16)
    ax[i].legend() 
#################################################################################

# for i in range(3):
    
#     for j in range(x):
#         s1=np.load(os.path.join(basedir,result[i*x+j]))
#         p=es_point(s1,500)
#         ax[i].plot(s1[0][:p],s1[2][:p], label=lab[i*x+j])
# #         index_max=np.argmax(s1[2])
# #         ax[i].plot(index_max,s1[2][index_max],'ks')
# #         ax[i].annotate('{:.3f}'.format(s1[2][index_max]),
# #                        xytext=(index_max,s1[2][index_max]),
# #                        xy=(index_max,s1[2][index_max])
# #                       )
    
    
#     ax[i].set_xlabel('Epoch',fontsize=16)
#     ax[i].set_ylim([0, 1])
#     ax[i].grid(axis="y",ls='-.')
#     ax[0].set_ylabel('Accuracy',fontsize=16)
#     ax[i].legend()

# %% [markdown]
# ## Share Data

# %%
basedir=os.path.join('ShareData')
os.listdir(basedir)
# Out:
# ['zOLD']

# %%
# fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True, figsize=(18, 6))


# result=[
#     '1c.10w.4000.share100.epo_iid.loc1.earlystop500.20200502-044312.npy',
#     '1c.10w.4000.share100.loc1.earlystop500.20200501-214132.npy',
#     '1c.10w.8000.share100.loc1.earlystop500.20200501-224713.npy',
#     '1c.40w.4000.share100.loc1.earlystop500.20200502-143313.npy',
#     'iid.10w.4000.share100.loc1.earlystop500.20200502-075909.npy',

#     '1c.10w.4000.share400.epo_iid.loc1.earlystop500.20200502-182749.npy',
#     '1c.10w.4000.share400.loc1.earlystop500.20200502-043110.npy',
#     '1c.10w.8000.share400.loc1.earlystop500.20200502-141458.npy',
#     '1c.40w.4000.share400.loc1.earlystop500.20200503-004916.npy',
#     'iid.10w.4000.share400.loc1.earlystop500.20200502-084100.npy',
        
#     '1c.10w.4000.share800.epo_iid.loc1.earlystop500.20200503-204042.npy',
#     '1c.10w.4000.share800.loc1.earlystop500.20200502-154752.npy',
#     '1c.10w.8000.share800.loc1.earlystop500.20200503-074544.npy',
#     '1c.40w.4000.share800.loc1.earlystop500.20200503-062946.npy',
#     'iid.10w.4000.share800.loc1.earlystop500.20200503-081409.npy',
# ]

# node_dir = [
#     'sdes1',
#     'sdns1',
#     'sssdn1',
#     'sdn40ws100',
#     'sdiid1',

#     'sdes4',
#     'sdns4',
#     'sssdn4',
#     'sdn40ws400',
#     'sdiid4',    
    
#     'sdes8',
#     'sdns8',
#     'sssdn8',
#     'sdn40ws800',
#     'sdiid8',    
        
# ]


# # for i in range(3):        
# #     for j in [1,4]:
# #         s1=np.load(os.path.join(basedir,result[i*5+j]))
# #         p=es_point(s1,500)
# #         half_window_size=25
# #         (s_mean,s_varience)=windowed(s1[2][:p],half_window_size)
# #         s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
# # #         ax[i].plot(s_epo,s_mean, label=result[i*5+j][:-38])
# #         ax[i].plot(s_epo[20:],s_varience[20:], label=result[i*5+j][:-38]+'_var')

# #             # see how training data fit
# #         files = glob.glob(basedir +'/'+ node_dir[i*5+j]+ '/worker_nodes/*/self_EVAL.txt')
# #         linelab = result[i*5+j][:-38] + '_traindata'
# #         set_mean = plot_line(files,i,linelab)
# #         (s_mean,s_varience)=windowed(set_mean,half_window_size)
# #         s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
# # #         ax[i].plot(s_epo,s_mean, label=linelab)
# #         ax[i].plot(s_epo[20:],s_varience[20:], label=linelab+'_var')

    
# #     ax[i].set_xlabel('Epoch',fontsize=16)
# #     ax[i].grid(axis="y",ls='-.')
# #     ax[0].set_ylabel('Accuracy',fontsize=16)
# #     ax[i].legend() 

# #########################################################################################

# for i in range(3):        
#     for j in [1,4]:
#         s1=np.load(os.path.join(basedir,result[i*5+j]))
#         p=es_point(s1,500)
#         ax[i].plot(s1[0][:p],s1[2][:p], label=result[i*5+j][:-38]) ########!!!!
# #         index_max=np.argmax(s1[2])
# #         ax[i].plot(index_max,s1[2][index_max],'ks')
# #         ax[i].annotate('{:.3f}'.format(s1[2][index_max]),
# #                        xytext=(index_max,s1[2][index_max]),
# #                        xy=(index_max,s1[2][index_max])
# #                       )
    
    
#     ax[i].set_xlabel('Epoch',fontsize=16)
#     ax[i].grid(axis="y",ls='-.')
#     ax[0].set_ylabel('Accuracy',fontsize=16)
#     ax[i].legend()

# %% [markdown]
# ## Late update in some node

# %%
basedir=os.path.join('DelayUpdate')
os.listdir(basedir)
# Out:
# ['2c.40w.4000.dly20.speed3.loc1.earlystop500.20200502-160017.npy',
#  '2c.40w.4000.dly32.speed3.loc1.earlystop500.20200430-223516.npy',
#  '2c.40w.4000.dly8.speed12.loc1.earlystop500.20200502-161123.npy',
#  '2c.40w.4000.dly8.speed3.loc1.earlystop500.20200503-013135.npy',
#  '2c.40w.4000.dly8.speed30.loc1.earlystop500.20200503-084238.npy',
#  '5c.40w.4000.dly32.speed3.loc1.earlystop500.20200503-210047.npy',
#  '5c.40w.4000.dly8.speed12.loc1.earlystop500.20200502-171548.npy',
#  '5c.40w.4000.dly8.speed3.loc1.earlystop500.20200502-160044.npy',
#  '5c.40w.4000.dly8.speed30.loc1.earlystop500.20200502-182343.npy',
#  'du2c1',
#  'du2c2',
#  'du2c3',
#  'du2c4',
#  'du2c5',
#  'du5c1',
#  'du5c3',
#  'du5c4',
#  'du5c5',
#  'duiid1',
#  'duiid2',
#  'duiid3',
#  'duiid4',
#  'duiid5',
#  'iid.40w.4000.dly20.speed3.loc1.earlystop500.20200503-002016.npy',
#  'iid.40w.4000.dly32.speed3.loc1.earlystop500.20200502-184247.npy',
#  'iid.40w.4000.dly8.speed12.loc1.earlystop500.20200502-133739.npy',
#  'iid.40w.4000.dly8.speed3.loc1.earlystop500.20200502-193120.npy',
#  'iid.40w.4000.dly8.speed30.loc1.earlystop500.20200503-184146.npy']

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True, figsize=(18, 6))

# in order: dly8-30/12/3, dly20, dly32
result=[
    '2c.40w.4000.dly8.speed3.loc1.earlystop500.20200503-013135.npy',
    '2c.40w.4000.dly20.speed3.loc1.earlystop500.20200502-160017.npy',
    '2c.40w.4000.dly32.speed3.loc1.earlystop500.20200430-223516.npy',
    '2c.40w.4000.dly8.speed12.loc1.earlystop500.20200502-161123.npy',
    '2c.40w.4000.dly8.speed30.loc1.earlystop500.20200503-084238.npy',
        
   
    '5c.40w.4000.dly8.speed3.loc1.earlystop500.20200502-160044.npy',
    '5c.40w.4000.dly8.speed3.loc1.earlystop500.20200502-160044.npy', #
    '5c.40w.4000.dly32.speed3.loc1.earlystop500.20200503-210047.npy', 
    '5c.40w.4000.dly8.speed12.loc1.earlystop500.20200502-171548.npy',
    '5c.40w.4000.dly8.speed30.loc1.earlystop500.20200502-182343.npy',
        
    
    'iid.40w.4000.dly8.speed3.loc1.earlystop500.20200502-193120.npy',
    'iid.40w.4000.dly20.speed3.loc1.earlystop500.20200503-002016.npy',
    'iid.40w.4000.dly32.speed3.loc1.earlystop500.20200502-184247.npy', 
    'iid.40w.4000.dly8.speed12.loc1.earlystop500.20200502-133739.npy',
    'iid.40w.4000.dly8.speed30.loc1.earlystop500.20200503-184146.npy', 
]

lab=[
    '2c.dly20%.speed3',
    '2c.dly50%.speed3',
    '2c.dly80%.speed3',
    '2c.dly20%.speed12',
    '2c.dly20%.speed30',
        
   
    '5c.dly20%.speed3',
    '5c.dly20%.speed3', #50%
    '5c.dly80%.speed3', 
    '5c.dly20%.speed12',
    '5c.dly20%.speed30',
        
    
    'iid.dly20%.speed3',
    'iid.dly50%.speed3',
    'iid.dly80%.speed3', 
    'iid.dly20%.speed12',
    'iid.dly20%.speed30', 
]


node_dir = [
    'du2c1',
    'du2c2',
    'du2c3',
    'du2c4',
    'du2c5',
    'du5c1',
    'du5c1',#
    'du5c3',
    'du5c4',
    'du5c5',
    'duiid1',
    'duiid2',
    'duiid3',
    'duiid4',
    'duiid5'
]





for i in range(3):
    for j in range(3):
        j = j+2
        s1=np.load(os.path.join(basedir,result[i*5+j]))
        half_window_size=25
        (s_mean,s_varience)=windowed(s1[2],half_window_size)
        s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
        ax[i].plot(s_epo,s_mean, label=lab[i*5+j])
#         ax[i].plot(s_epo[10:],s_varience[10:], label=lab[i*5+j]+'_var')
    
    
        # see how training data fit
        files = glob.glob(basedir +'/'+ node_dir[i*5+j]+ '/worker_nodes/*/self_EVAL.txt')
        linelab = lab[i*2+j] + '_traindata'
        set_mean = plot_line(files,i,linelab)
        (s_mean,s_varience)=windowed(set_mean,half_window_size)
        s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
        ax[i].plot(s_epo,s_mean, label=linelab)
#         ax[i].plot(s_epo[10:],s_varience[10:], label=linelab+'_var')    

    ax[i].set_xlabel('Epoch',fontsize=16)
    ax[i].set_ylim([0, 1.1])
    ax[i].grid(axis="y",ls='-.')
    ax[0].set_ylabel('Accuracy',fontsize=16)
    ax[i].legend() 


####################################################################################

# for i in range(3):
#     for j in range(3):
#         j = j+2
#         s1=np.load(os.path.join(basedir,result[i*5+j]))
#         p=es_point(s1,500)
#         ax[i].plot(s1[0][:p],s1[2][:p], label=lab[i*5+j])
# #         index_max=np.argmax(s1[2])
# #         ax[i].plot(index_max,s1[2][index_max],'ks')
# #         ax[i].annotate('{:.3f}'.format(s1[2][index_max]),
# #                        xytext=(index_max,s1[2][index_max]),
# #                        xy=(index_max,s1[2][index_max])
# #                       )
    
    
#     ax[i].set_xlabel('Epoch',fontsize=16)
#     ax[i].set_ylim([0, 1])
#     ax[i].grid(axis="y",ls='-.')
#     ax[0].set_ylabel('Accuracy',fontsize=16)
#     ax[i].legend()

# %% [markdown]
# ## Evaluate by node

# %%
basedir=os.path.join('EvalTest')
os.listdir(basedir)
# Out:
# ['2c.10w.4000_node_EVL.loc1.earlystop500.20200502-172929.npy',
#  '5c.10w.4000_node_EVL.loc1.earlystop500.20200502-092327.npy',
#  'evl2c',
#  'evl5c',
#  'evliid',
#  'iid.10w.4000_node_EVL.loc1.earlystop500.20200502-141431.npy']

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, sharex=True, sharey=True, figsize=(18, 6))


result=[
    '2c.10w.4000_node_EVL.loc1.earlystop500.20200502-172929.npy',
    '5c.10w.4000_node_EVL.loc1.earlystop500.20200502-092327.npy',
    'iid.10w.4000_node_EVL.loc1.earlystop500.20200502-141431.npy',
    'evl2c',
    'evl5c',
    'evliid'
]

lab=[
    '2c',
    '5c',
    'iid'   
]



# for i in range(3):
#     half_window_size=25
    
#     s1=np.load(os.path.join(basedir,result[i]))
#     (s_mean,s_varience)=windowed(s1[2][:p],half_window_size)
#     s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
#     ax[i].plot(s_epo,s_mean, label=lab[i]+'_centralEVAL')    


#     files = glob.glob(basedir +'/'+result[i+3]+ '/worker_nodes/*/node_EVAL_before_training.txt')
#     linelab = lab[i]+'_node_EVAL'
#     set_mean = plot_line(files,i,linelab)
#     (s_mean,s_varience)=windowed(set_mean,half_window_size)
#     s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
#     ax[i].plot(s_epo,s_mean, label=linelab)
    
#     files = glob.glob(basedir +'/'+result[i+3]+ '/worker_nodes/*/node_EVAL_after_training.txt')
#     linelab = lab[i]+'_node_EVAL_before_merge_weight'
#     set_mean = plot_line(files,i,linelab)
#     (s_mean,s_varience)=windowed(set_mean,half_window_size)
#     s_epo=[i+half_window_size+1 for i in range(len(s_mean))]
#     ax[i].plot(s_epo,s_mean, label=linelab)

    
    
#     ax[i].set_xlabel('Epoch',fontsize=16)
#     ax[i].set_ylim([0, 1])
#     ax[i].grid(axis="y",ls='-.')
#     ax[0].set_ylabel('Accuracy',fontsize=16)
#     ax[i].legend() 

################################################################################################

for i in range(3):
    s1=np.load(os.path.join(basedir,result[i]))
    ax[i].plot(s1[0],s1[2], label=lab[i]+'_centralEVAL')


    files = glob.glob(basedir +'/'+result[i+3]+ '/worker_nodes/*/node_EVAL_before_training.txt')
    linelab = lab[i]+'_node_EVAL'
    set_mean = plot_line(files,i,linelab)
    s_epo=[i+1 for i in range(len(set_mean))]
    ax[i].plot(s_epo,set_mean, label=linelab)
    
    files = glob.glob(basedir +'/'+result[i+3]+ '/worker_nodes/*/node_EVAL_after_training.txt')
    linelab = lab[i]+'_node_EVAL_before_merge_weight'
    set_mean = plot_line(files,i,linelab)
    s_epo=[i+1 for i in range(len(set_mean))]
    ax[i].plot(s_epo,set_mean, label=linelab)

    
    
    ax[i].set_xlabel('Epoch',fontsize=16)
    ax[i].set_ylim([0, 1])
    ax[i].grid(axis="y",ls='-.')
    ax[0].set_ylabel('Accuracy',fontsize=16)
    ax[i].legend()
